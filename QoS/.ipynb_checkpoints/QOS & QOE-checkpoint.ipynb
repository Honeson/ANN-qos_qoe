# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
print ('I am ready to dive right in')
# Out:
# I am ready to dive right in

# %% [markdown]
# Step 1:Importing the Dataset named qosqoeNew.csv and checking the first 20 rows

# %%
qos_qoe= pd.read_csv('qosqoeNew.csv')
qos_qoe.head(20)
# Out:
#    #RequestID NbClients BottleneckBW BottleneckDelay BottleneckLoss DASHPolicy ClientResolution RequestDuration TCPOutputPacket TCPOutputDelay TCPOutputJitter TCPOutputPloss TCPInputPacket TCPInputDelay TCPInputJitter TCPInputPloss TCPInputRetrans StdInputRate 0_InputRateVariation 5_InputRateVariation 10_InputRateVariation 25_InputRateVariation 50_InputRateVariation 75_InputRateVariation 90_InputRateVariation 95_InputRateVariation 100_InputRateVariation StdInterATimesReq 0_InterATimesReq 5_InterATimesReq 10_InterATimesReq 25_InterATimesReq 50_InterATimesReq 75_InterATimesReq 90_InterATimesReq 95_InterATimesReq 100_InterATimesReq StartUpDelay AvgDownloadRate StdDownloadRate AvgBufferLevel StdBufferLevel StallEvents RebufferingRatio StallLabel TotalStallingTime AvgTimeStallingEvents AvgQualityIndex AvgVideoBitRate AvgVideoQualityVariation AvgDownloadBitRate
# 0   1 11 15950000 1 0 RateBasedAdaptationLogic 640...
# 1   2 11 15950000 1 0 RateBasedAdaptationLogic 640...
# 2   3 11 15950000 1 0 RateBasedAdaptationLogic 640...
# 3   4 11 15950000 1 0 RateBasedAdaptationLogic 640...
# 4   5 11 15950000 1 0 RateBasedAdaptationLogic 640...
# 5   6 11 15950000 1 0 RateBasedAdaptationLogic 640...
# 6   7 11 15950000 1 0 RateBasedAdaptationLogic 640...
# 7   8 11 15950000 1 0 RateBasedAdaptationLogic 640...
# 8   9 11 15950000 1 0 RateBasedAdaptationLogic 640...
# 9   10 11 15950000 1 0 RateBasedAdaptationLogic 64...
# 10  11 11 15950000 1 0 RateBasedAdaptationLogic 64...
# 11  1 11 15950000 1 0.01 BufferBasedAdaptationLogi...
# 12  2 11 15950000 1 0.01 BufferBasedAdaptationLogi...
# 13  3 11 15950000 1 0.01 BufferBasedAdaptationLogi...
# 14  4 11 15950000 1 0.01 BufferBasedAdaptationLogi...
# 15  5 11 15950000 1 0.01 BufferBasedAdaptationLogi...
# 16  6 11 15950000 1 0.01 BufferBasedAdaptationLogi...
# 17  7 11 15950000 1 0.01 BufferBasedAdaptationLogi...
# 18  8 11 15950000 1 0.01 BufferBasedAdaptationLogi...
# 19  9 11 15950000 1 0.01 BufferBasedAdaptationLogi...

# %% [markdown]
# Step 2: Check the description of the dataset and also the column headers while dropping the unnecessary ones.

# %%
qos_qoe.describe()
# Out:
#          #RequestID     NbClients  BottleneckBW  BottleneckDelay  \
# count  69129.000000  69129.000000  6.912900e+04     69129.000000
# mean      26.269438     55.791477  2.616060e+08        36.089615
# std       19.403130     20.368601  1.827508e+08        22.842334
# min        1.000000      1.000000  5.000000e+05         1.000000
# 25%       10.000000     41.000000  1.029500e+08        21.000000
# 50%       22.000000     61.000000  2.378500e+08        41.000000
# 75%       39.000000     71.000000  3.782000e+08        61.000000
# max       81.000000     81.000000  7.330500e+08        71.000000
#
#        BottleneckLoss  ClientResolution  RequestDuration  TCPOutputPacket  \
# count    69129.000000      6.912900e+04          69129.0     69129.000000
# mean         0.008233      6.578972e+06             70.0      9043.195663
# std          0.007950      8.420881e+06              0.0      7692.084952
# min          0.000000      6.403600e+05             70.0       567.000000
# 25%          0.000000      6.403600e+05             70.0      2504.000000
# 50%          0.010000      1.280720e+06             70.0      5410.000000
# 75%          0.010000      1.920108e+07             70.0     14585.000000
# max          0.020000      1.920108e+07             70.0     30995.000000
#
#        TCPOutputDelay  TCPOutputJitter  ...  AvgBufferLevel  StdBufferLevel  \
# count    69129.000000     69129.000000  ...    69129.000000    69129.000000
# mean        36.109935         0.001916  ...       10.103738        3.964655
# std         22.842551         0.004691  ...        6.585241        1.845889
# min          1.015090         0.000209  ...        0.000000        0.000000
# 25%         21.015200         0.000395  ...        3.771430        2.470590
# 50%         41.015200         0.001084  ...       10.628600        4.115080
# 75%         61.015200         0.002314  ...       13.411800        4.944100
# max         72.007100         0.249556  ...       27.428600       11.710800
#
#         StallEvents  RebufferingRatio  TotalStallingTime  \
# count  69129.000000      69129.000000       69129.000000
# mean       0.572018          0.009134         639.410378
# std        1.223810          0.022647        1585.301157
# min        0.000000          0.000000           0.000000
# 25%        0.000000          0.000000           0.000000
# 50%        0.000000          0.000000           0.000000
# 75%        1.000000          0.001429         100.000000
# max       19.000000          0.371429       26000.000000
#
#        AvgTimeStallingEvents  AvgQualityIndex  AvgVideoBitRate  \
# count           69129.000000     69129.000000     6.912900e+04
# mean               20.484805         0.666145     2.007629e+06
# std                53.423785         0.150264     1.622589e+06
# min                 0.000000         0.250000     2.406400e+05
# 25%                 0.000000         0.564286     5.845840e+05
# 50%                 0.000000         0.692857     1.320000e+06
# 75%                 3.125000         0.764286     3.450000e+06
# max              1368.420000         1.000000     5.800000e+06
#
#        AvgVideoQualityVariation  AvgDownloadBitRate
# count              6.912900e+04        6.912900e+04
# mean               3.496549e+05        3.171012e+06
# std                3.465975e+05        3.103498e+06
# min                0.000000e+00        1.685320e+05
# 25%                1.209220e+05        7.971640e+05
# 50%                1.942400e+05        1.800000e+06
# 75%                5.014590e+05        4.830000e+06
# max                2.860000e+06        2.470000e+07
#
# [8 rows x 49 columns]

# %%
qos_qoe.columns
# Out:
# Index(['#RequestID', 'NbClients', 'BottleneckBW', 'BottleneckDelay',
#        'BottleneckLoss', 'DASHPolicy', 'ClientResolution', 'RequestDuration',
#        'TCPOutputPacket', 'TCPOutputDelay', 'TCPOutputJitter',
#        'TCPOutputPloss', 'TCPInputPacket', 'TCPInputDelay', 'TCPInputJitter',
#        'TCPInputPloss', 'TCPInputRetrans', 'StdInputRate',
#        '0_InputRateVariation', '5_InputRateVariation', '10_InputRateVariation',
#        '25_InputRateVariation', '50_InputRateVariation',
#        '75_InputRateVariation', '90_InputRateVariation',
#        '95_InputRateVariation', '100_InputRateVariation', 'StdInterATimesReq',
#        '0_InterATimesReq', '5_InterATimesReq', '10_InterATimesReq',
#        '25_InterATimesReq', '50_InterATimesReq', '75_InterATimesReq',
#        '90_InterATimesReq', '95_InterATimesReq', '100_InterATimesReq',
#        'StartUpDelay', 'AvgDownloadRate', 'StdDownloadRate', 'AvgBufferLevel',
#        'StdBufferLevel', 'StallEvents', 'RebufferingRatio', 'StallLabel',
#        'TotalStallingTime', 'AvgTimeStallingEvents', 'AvgQualityIndex',
#        'AvgVideoBitRate', 'AvgVideoQualityVariation', 'AvgDownloadBitRate'],
#       dtype='object')

# %%
qos_qoe.drop([ 'TCPInputPloss', 'TCPInputRetrans', 'StdInputRate',
       '0_InputRateVariation', '5_InputRateVariation', '10_InputRateVariation',
       '25_InputRateVariation', '50_InputRateVariation',
       '75_InputRateVariation', '90_InputRateVariation',
       '95_InputRateVariation', '100_InputRateVariation', 'StdInterATimesReq',
       '0_InterATimesReq', '5_InterATimesReq', '10_InterATimesReq',
       '25_InterATimesReq', '50_InterATimesReq', '75_InterATimesReq',
       '90_InterATimesReq', '95_InterATimesReq', '100_InterATimesReq'], axis = 1)
# Out:
#        #RequestID  NbClients  BottleneckBW  BottleneckDelay  BottleneckLoss  \
# 0               1         11      15950000                1            0.00
# 1               2         11      15950000                1            0.00
# 2               3         11      15950000                1            0.00
# 3               4         11      15950000                1            0.00
# 4               5         11      15950000                1            0.00
# ...           ...        ...           ...              ...             ...
# 69124          13         81     733050000                1            0.02
# 69125          14         81     733050000                1            0.02
# 69126          15         81     733050000                1            0.02
# 69127          16         81     733050000                1            0.02
# 69128          17         81     733050000                1            0.02
#
#                               DASHPolicy  ClientResolution  RequestDuration  \
# 0               RateBasedAdaptationLogic            640360               70
# 1               RateBasedAdaptationLogic            640360               70
# 2               RateBasedAdaptationLogic            640360               70
# 3               RateBasedAdaptationLogic            640360               70
# 4               RateBasedAdaptationLogic            640360               70
# ...                                  ...               ...              ...
# 69124  RateAndBufferBasedAdaptationLogic          19201080               70
# 69125  RateAndBufferBasedAdaptationLogic          19201080               70
# 69126  RateAndBufferBasedAdaptationLogic          19201080               70
# 69127  RateAndBufferBasedAdaptationLogic          19201080               70
# 69128  RateAndBufferBasedAdaptationLogic          19201080               70
#
#        TCPOutputPacket  TCPOutputDelay  ...  StdBufferLevel  StallEvents  \
# 0                 3451         1.04339  ...         2.39988            0
# 1                 3918         1.04333  ...         4.37830            1
# 2                 4833         1.04291  ...         4.54182            1
# 3                 9195         1.04220  ...         1.14856            0
# 4                 5766         1.04259  ...         1.50753            0
# ...                ...             ...  ...             ...          ...
# 69124            28550         1.01511  ...         8.78886            0
# 69125            27436         1.01511  ...         8.79592            0
# 69126            24703         1.01511  ...         7.94471            1
# 69127            23616         1.01513  ...         7.79953            1
# 69128            27433         1.01511  ...         9.91392            1
#
#        RebufferingRatio    StallLabel  TotalStallingTime  \
# 0              0.000000    NoStalling                  0
# 1              0.011429  MildStalling                800
# 2              0.010000  MildStalling                700
# 3              0.000000    NoStalling                  0
# 4              0.000000    NoStalling                  0
# ...                 ...           ...                ...
# 69124          0.000000    NoStalling                  0
# 69125          0.000000    NoStalling                  0
# 69126          0.020000  MildStalling               1400
# 69127          0.005714  MildStalling                400
# 69128          0.005714  MildStalling                400
#
#        AvgTimeStallingEvents  AvgQualityIndex  AvgVideoBitRate  \
# 0                     0.0000         0.590909         888242.0
# 1                    24.2424         0.691176         836819.0
# 2                    21.8750         0.590909         981488.0
# 3                     0.0000         0.900000        2760000.0
# 4                     0.0000         0.750000        1710000.0
# ...                      ...              ...              ...
# 69124                 0.0000         0.928571        4950000.0
# 69125                 0.0000         0.914286        4884480.0
# 69126                41.1765         0.907143        4630000.0
# 69127                11.7647         0.814286        4350000.0
# 69128                11.7647         0.885714        4710000.0
#
#        AvgVideoQualityVariation  AvgDownloadBitRate
# 0                      114080.0           1020000.0
# 1                      120863.0           1100000.0
# 2                      121440.0           1240000.0
# 3                      252988.0           3080000.0
# 4                      310664.0           1960000.0
# ...                         ...                 ...
# 69124                 1530000.0          13200000.0
# 69125                 1540000.0          13200000.0
# 69126                 1630000.0          11400000.0
# 69127                 2010000.0          12600000.0
# 69128                 1560000.0          12500000.0
#
# [69129 rows x 29 columns]

# %%
qos_qoe.describe()
# Out:
#          #RequestID     NbClients  BottleneckBW  BottleneckDelay  \
# count  69129.000000  69129.000000  6.912900e+04     69129.000000
# mean      26.269438     55.791477  2.616060e+08        36.089615
# std       19.403130     20.368601  1.827508e+08        22.842334
# min        1.000000      1.000000  5.000000e+05         1.000000
# 25%       10.000000     41.000000  1.029500e+08        21.000000
# 50%       22.000000     61.000000  2.378500e+08        41.000000
# 75%       39.000000     71.000000  3.782000e+08        61.000000
# max       81.000000     81.000000  7.330500e+08        71.000000
#
#        BottleneckLoss  ClientResolution  RequestDuration  TCPOutputPacket  \
# count    69129.000000      6.912900e+04          69129.0     69129.000000
# mean         0.008233      6.578972e+06             70.0      9043.195663
# std          0.007950      8.420881e+06              0.0      7692.084952
# min          0.000000      6.403600e+05             70.0       567.000000
# 25%          0.000000      6.403600e+05             70.0      2504.000000
# 50%          0.010000      1.280720e+06             70.0      5410.000000
# 75%          0.010000      1.920108e+07             70.0     14585.000000
# max          0.020000      1.920108e+07             70.0     30995.000000
#
#        TCPOutputDelay  TCPOutputJitter  ...  AvgBufferLevel  StdBufferLevel  \
# count    69129.000000     69129.000000  ...    69129.000000    69129.000000
# mean        36.109935         0.001916  ...       10.103738        3.964655
# std         22.842551         0.004691  ...        6.585241        1.845889
# min          1.015090         0.000209  ...        0.000000        0.000000
# 25%         21.015200         0.000395  ...        3.771430        2.470590
# 50%         41.015200         0.001084  ...       10.628600        4.115080
# 75%         61.015200         0.002314  ...       13.411800        4.944100
# max         72.007100         0.249556  ...       27.428600       11.710800
#
#         StallEvents  RebufferingRatio  TotalStallingTime  \
# count  69129.000000      69129.000000       69129.000000
# mean       0.572018          0.009134         639.410378
# std        1.223810          0.022647        1585.301157
# min        0.000000          0.000000           0.000000
# 25%        0.000000          0.000000           0.000000
# 50%        0.000000          0.000000           0.000000
# 75%        1.000000          0.001429         100.000000
# max       19.000000          0.371429       26000.000000
#
#        AvgTimeStallingEvents  AvgQualityIndex  AvgVideoBitRate  \
# count           69129.000000     69129.000000     6.912900e+04
# mean               20.484805         0.666145     2.007629e+06
# std                53.423785         0.150264     1.622589e+06
# min                 0.000000         0.250000     2.406400e+05
# 25%                 0.000000         0.564286     5.845840e+05
# 50%                 0.000000         0.692857     1.320000e+06
# 75%                 3.125000         0.764286     3.450000e+06
# max              1368.420000         1.000000     5.800000e+06
#
#        AvgVideoQualityVariation  AvgDownloadBitRate
# count              6.912900e+04        6.912900e+04
# mean               3.496549e+05        3.171012e+06
# std                3.465975e+05        3.103498e+06
# min                0.000000e+00        1.685320e+05
# 25%                1.209220e+05        7.971640e+05
# 50%                1.942400e+05        1.800000e+06
# 75%                5.014590e+05        4.830000e+06
# max                2.860000e+06        2.470000e+07
#
# [8 rows x 49 columns]
